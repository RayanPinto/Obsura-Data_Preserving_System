# %% [markdown]
# # Live Data Analysis Pipeline
# ## Connecting Mobile App Data to ML Models
#
# This notebook processes live data from your mobile app and runs ML models on it.

# %%
# Install required packages
# %pip install supabase pandas numpy scikit-learn pycryptodome matplotlib seaborn

# %%
# Connect to your Supabase database and fetch live data
import pandas as pd
import numpy as np
from supabase import create_client, Client
from datetime import datetime
import matplotlib.pyplot as plt

# Your Supabase credentials
SUPABASE_URL = "https://wedprccshkryxfzhjyvl.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6IndlZHByY2NzaGtyeXhmemhqeXZsIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTcxNzk0MDksImV4cCI6MjA3Mjc1NTQwOX0.jvyWP-sYoUiJqNyG73Zczu_cSbOdUnJXtAdZ1Wsbk-g"

supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)
print("✅ Connected to Supabase database!")

# Fetch live survey data from your mobile app
response = supabase.table('fable').select('*').execute()
live_survey_data = pd.DataFrame(response.data)
print(f"📊 Retrieved {len(live_survey_data)} survey records from mobile app")

# Fetch live OCR data 
response_ocr = supabase.table('ocr').select('*').execute()
live_ocr_data = pd.DataFrame(response_ocr.data)
print(f"📱 Retrieved {len(live_ocr_data)} OCR records from mobile app")

print("\n🎉 YOUR MOBILE APP DATA IS NOW CONNECTED TO JUPYTER!")
print("This means every time someone submits a survey or uses OCR,")
print("this notebook can analyze that data in real-time!")
